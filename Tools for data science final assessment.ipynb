# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Vincent Tsang Kai Yu, Operation Analyst**

# %% [markdown]
# *I am interested in data science because I would like to seize the chance in pursue
# in my career, both to enjoy the challenges appointed and to sharpen
# myself up. In the era of big data, every tiny bit of data could be
# tracked down and turned into money. During my process in Kaggle
# Competition, we have been developing solutions for risk assurance
# such as detecting fraudulence. Despite the above field, I am also
# intrigued in the field of artificial intelligence, like facial recognition and
# deep learning, etc.*

# %% [markdown]
# ###Perform string slicing on the conditions below

# %%
string = 'I am interested in data science'
if len(string)>0:
    print(string[5:])
else:
    print(string[:3])
    print(string[3:5])
# Out:
# interested in data science

# %% [markdown]
# - Animal
# - Water
# - Plant
#     - Flower
#     - Tree
# - Soil
#
# 1. Animal
# 2. Water
# 3. Plant
# 4. Flower
# 5. Tree
# 6. Soil
#
# ---
# Hi this is a horizontal rule
#
# ---
#
# In the above codes, use `print()` to print to console.
#
#
# >I am interested in data science because I would like to seize the chance in pursue
# in my career, both to enjoy the challenges appointed and to sharpen
# myself up. In the era of big data, every tiny bit of data could be
# tracked down and turned into money. During my process in Kaggle
# Competition, we have been developing solutions for risk assurance
# such as detecting fraudulence. Despite the above field, I am also
# intrigued in the field of artificial intelligence, like facial recognition and
# deep learning, etc
#
# - [x] task 1
# - [ ] task 2 (not yet finished)
#
# https://www.ibm.com/hk-en
#
# ![image.png](attachment:image.png)
